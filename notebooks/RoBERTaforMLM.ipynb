# %% [markdown]
# # Retraining RoBERTa for MLM
#
# Retraining roberta-base for masked language model (MLM) using the RoBERTa pre-training procedure

# %%
# It is oftentimes desirable to re-train the LM to better capture the language characteristics of a downstream task.

# A recently published work BerTweet (Nguyen et al., 2020) provides a pre-trained BERT model 
# (using the RoBERTa procedure) on vast Twitter corpora in English. 
# They argue that BerTweet better models the characteristic of language used on the Twitter subspace, 
# outperforming previous SOTA models on Tweet NLP tasks.

# That is, the performance on downstream tasks is can be greatly influenced by what our LM captures!

# %% [markdown]
# ### Create Virtual Environment
#
# https://janakiev.com/blog/jupyter-virtual-envs/

# %%
# ! pip install --user virtualenv

# %%
# ! python -m venv venv_robarta

# %%
# ! source venv_robarta/bin/activate

# %%
# ! pip install --user ipykernel
# ! jupyter kernelspec uninstall myenv

# %%
# ! python -m ipykernel install --user --name=venv_robarta

# %% [markdown]
# ### 0. Get Data
#
# Get Hate Speech Detection dataset (Basile et al., 2019) made available through TweetEval (Barbieri et al., 2020).

# %%
# !git clone https://github.com/cardiffnlp/tweeteval /tmp/tweeteval

# %% [markdown]
# ## 1. Include required libraries

# %%
# ! pip install torch==1.4.0 torchvision==0.5.0
# ! pip install transformers==3.5.1
from transformers import RobertaTokenizer, RobertaForMaskedLM
from transformers import LineByLineTextDataset
from transformers import DataCollatorForLanguageModeling
from transformers import Trainer, TrainingArguments

# %%
# import transformers
# transformers.__version__

# %%
# import torch
# torch.__version__

# %%
# ! pip -V

# %% [markdown]
# ## 2. Prepare Data

# %% [markdown]
# ### 2.1 Create tokenizer and model object

# %%
tokenizer = RobertaTokenizer.from_pretrained('roberta-base')
model = RobertaForMaskedLM.from_pretrained('roberta-base')

# %% [markdown]
# ### 2.2 LineByLineTextDataset class
#
# Since our data is already present in a single file, we can go ahead and use the LineByLineTextDataset class.

# %%
# The block_size argument gives the largest token length supported by the LM to be trained. 
# “roberta-base” supports sequences of length 512 (including special tokens like <s> (start of sequence) and </s> (end of sequence).

dataset = LineByLineTextDataset(
    tokenizer=tokenizer,
    file_path="./data/messagesForX.txt",
    block_size=512,
)

# %% [markdown]
# ### 2.3. Data collator
#
# The data collator object helps us to form input data batches in a form on which the LM can be trained. For example, it pads all examples of a batch to bring them to the same length.

# %%
data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer, mlm=True, mlm_probability=0.15
)

# %% [markdown]
# ## 3. Training Model

# %% [markdown]
# ### 3.1 Training object
#
# TrainingArguments object holds some fields that help define the training process. The Trainer finally brings all of the objects that we have created till now together to facilitate the train process.
#
# seed=1: seeds the RNG for the Trainer so that the results can be replicated when needed.

# %%
training_args = TrainingArguments(
    output_dir="./roberta-retrained",
    overwrite_output_dir=True,
    num_train_epochs=25,
    per_device_train_batch_size=48,
    save_steps=500,
    save_total_limit=2,
    seed=1
)

trainer = Trainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=dataset
)

# %% [markdown]
# ### 3.2 Run training
#
# trainer.save_model(output_dir): helps us save the model to the output_dir so that we can load it using from_pretrained (or as done below).

# %%
# import torch
# torch.__version__

# %%
trainer.train()

trainer.save_model("./roberta-retrained")

# %%
from transformers import RobertaTokenizer, TFRobertaModel
import tensorflow as tf

tokenizer = RobertaTokenizer.from_pretrained('roberta-base')

MASK_TOKEN = tokenizer.mask_token
model = TFRobertaModel.from_pretrained("./models/roberta-retrained", from_pt=True)


text = f"Hey {MASK_TOKEN} would you like to {MASK_TOKEN} and make a living {MASK_TOKEN} ?"

chats = \
    f"Let’s talk about your {MASK_TOKEN}! I am looking for new {MASK_TOKEN} for the fintech company Blackrock to further increase its {MASK_TOKEN}.\
    Based on your {MASK_TOKEN}, I believe you, {MASK_TOKEN}, could be {MASK_TOKEN} in our {MASK_TOKEN}.\
    Find the details here: https://careers.blackrock.com/job/16845601/ {MASK_TOKEN}\
    If you're {MASK_TOKEN}, please let me know your {MASK_TOKEN} and your {MASK_TOKEN} for a {MASK_TOKEN}.\
    What {MASK_TOKEN} Blackrock {MASK_TOKEN} {MASK_TOKEN}?: {MASK_TOKEN}\
    {MASK_TOKEN}, {MASK_TOKEN}, and {MASK_TOKEN}."

encoded_input = tokenizer(chats, return_tensors='tf')

from transformers import pipeline
clf = pipeline("fill-mask", model="./models/roberta-retrained", tokenizer=tokenizer)
answer = clf(chats)
answer
# Out:
# loading file vocab.json from cache at /Users/adarmani/.cache/huggingface/hub/models--roberta-base/snapshots/bc2764f8af2e92b6eb5679868df33e224075ca68/vocab.json
# loading file merges.txt from cache at /Users/adarmani/.cache/huggingface/hub/models--roberta-base/snapshots/bc2764f8af2e92b6eb5679868df33e224075ca68/merges.txt
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at None
# loading file tokenizer_config.json from cache at None
# loading configuration file config.json from cache at /Users/adarmani/.cache/huggingface/hub/models--roberta-base/snapshots/bc2764f8af2e92b6eb5679868df33e224075ca68/config.json
# Model config RobertaConfig {
#   "_name_or_path": "roberta-base",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.24.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading configuration file ./models/roberta-retrained/config.json
# Model config RobertaConfig {
#   "_name_or_path": "roberta-base",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "torch_dtype": "float32",
#   "transformers_version": "4.24.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading weights file ./models/roberta-retrained/pytorch_model.bin
# Loading PyTorch weights from /Users/adarmani/workspace/NLPLinkeInCoPilot/notebooks/models/roberta-retrained/pytorch_model.bin
# PyTorch checkpoint contains 124,697,947 parameters
# Loaded 124,055,040 parameters in the TF 2.0 model.
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFRobertaModel: ['roberta.embeddings.position_ids', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing TFRobertaModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFRobertaModel were not initialized from the PyTorch model and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# loading configuration file ./models/roberta-retrained/config.json
# Model config RobertaConfig {
#   "_name_or_path": "./models/roberta-retrained",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "torch_dtype": "float32",
#   "transformers_version": "4.24.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading configuration file ./models/roberta-retrained/config.json
# Model config RobertaConfig {
#   "_name_or_path": "./models/roberta-retrained",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "torch_dtype": "float32",
#   "transformers_version": "4.24.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading weights file ./models/roberta-retrained/pytorch_model.bin
# All model checkpoint weights were used when initializing RobertaForMaskedLM.
#
# All the weights of RobertaForMaskedLM were initialized from the model checkpoint at ./models/roberta-retrained.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use RobertaForMaskedLM for predictions without further training.
# [[{'score': 0.10631920397281647,
#    'token': 1142,
#    'token_str': ' questions',
#    'sequence': "<s>Let’s talk about your questions! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.07948160916566849,
#    'token': 2502,
#    'token_str': ' application',
#    'sequence': "<s>Let’s talk about your application! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.07747703045606613,
#    'token': 864,
#    'token_str': ' question',
#    'sequence': "<s>Let’s talk about your question! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.06759858131408691,
#    'token': 2956,
#    'token_str': ' ideas',
#    'sequence': "<s>Let’s talk about your ideas! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.045614730566740036,
#    'token': 12832,
#    'token_str': ' preference',
#    'sequence': "<s>Let’s talk about your preference! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"}],
#  [{'score': 0.3889772891998291,
#    'token': 2261,
#    'token_str': ' candidates',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new candidates for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.04611017554998398,
#    'token': 5392,
#    'token_str': ' directors',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new directors for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.0390915684401989,
#    'token': 1321,
#    'token_str': ' employees',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new employees for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.02894546650350094,
#    'token': 4389,
#    'token_str': ' managers',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new managers for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.0250796377658844,
#    'token': 10858,
#    'token_str': ' applicants',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new applicants for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"}],
#  [{'score': 0.04814613237977028,
#    'token': 3883,
#    'token_str': ' revenues',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its revenues.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.042943764477968216,
#    'token': 8243,
#    'token_str': ' flexibility',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its flexibility.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.04230129346251488,
#    'token': 2621,
#    'token_str': ' presence',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its presence.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.04229044169187546,
#    'token': 647,
#    'token_str': ' sales',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its sales.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.04008246213197708,
#    'token': 8680,
#    'token_str': ' profitability',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its profitability.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"}],
#  [{'score': 0.14657098054885864,
#    'token': 20259,
#    'token_str': ' CV',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your CV, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.10527492314577103,
#    'token': 6456,
#    'token_str': ' feedback',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your feedback, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.07960790395736694,
#    'token': 5209,
#    'token_str': ' presentation',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your presentation, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.05307801440358162,
#    'token': 6654,
#    'token_str': ' resume',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your resume, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.04577146843075752,
#    'token': 2502,
#    'token_str': ' application',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your application, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"}],
#  [{'score': 0.553281843662262,
#    'token': 350,
#    'token_str': ' too',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you, too, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.0953478217124939,
#    'token': 3086,
#    'token_str': ' Adam',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you, Adam, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.03712640330195427,
#    'token': 5329,
#    'token_str': ' indeed',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you, indeed, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.026782801374793053,
#    'token': 21958,
#    'token_str': ' sir',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you, sir, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.011660792864859104,
#    'token': 2512,
#    'token_str': ' yourself',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you, yourself, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"}],
#  [{'score': 0.6387962102890015,
#    'token': 2509,
#    'token_str': ' interested',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be interested in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.08996120095252991,
#    'token': 1165,
#    'token_str': ' included',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be included in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.05041603744029999,
#    'token': 963,
#    'token_str': ' involved',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be involved in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.041605670005083084,
#    'token': 1687,
#    'token_str': ' considered',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be considered in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.01408427581191063,
#    'token': 6051,
#    'token_str': ' participating',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be participating in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"}],
#  [{'score': 0.6680152416229248,
#    'token': 165,
#    'token_str': ' team',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our team.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.024404311552643776,
#    'token': 138,
#    'token_str': ' company',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our company.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.012420265935361385,
#    'token': 333,
#    'token_str': ' group',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our group.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.012269455939531326,
#    'token': 558,
#    'token_str': ' office',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our office.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.011395194567739964,
#    'token': 8118,
#    'token_str': ' listing',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our listing.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"}],
#  [{'score': 0.6736453771591187,
#    'token': 1437,
#    'token_str': ' ',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/     If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.1675311028957367,
#    'token': 479,
#    'token_str': '.',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/.    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.01483934000134468,
#    'token': 1666,
#    'token_str': '...',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/...    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.00622900715097785,
#    'token': 2156,
#    'token_str': ',',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/,    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.004407689906656742,
#    'token': 734,
#    'token_str': '...',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/...    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"}],
#  [{'score': 0.9593129754066467,
#    'token': 2509,
#    'token_str': ' interested',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're interested, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.01150989904999733,
#    'token': 4973,
#    'token_str': ' eligible',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're eligible, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.0049244859255850315,
#    'token': 577,
#    'token_str': ' available',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're available, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.004590992815792561,
#    'token': 6048,
#    'token_str': ' qualified',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're qualified, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.003025722224265337,
#    'token': 5609,
#    'token_str': ' keen',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're keen, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"}],
#  [{'score': 0.3977181613445282,
#    'token': 12832,
#    'token_str': ' preference',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your preference and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.2939774990081787,
#    'token': 766,
#    'token_str': ' name',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your name and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.08151588588953018,
#    'token': 3078,
#    'token_str': ' schedule',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your schedule and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.020804349333047867,
#    'token': 3471,
#    'token_str': ' requirements',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your requirements and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.01881345547735691,
#    'token': 16953,
#    'token_str': ' preferences',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your preferences and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"}],
#  [{'score': 0.46709996461868286,
#    'token': 12832,
#    'token_str': ' preference',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your preference for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.11358196288347244,
#    'token': 3078,
#    'token_str': ' schedule',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your schedule for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.053144652396440506,
#    'token': 3471,
#    'token_str': ' requirements',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your requirements for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.04231423884630203,
#    'token': 16953,
#    'token_str': ' preferences',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your preferences for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.03062114492058754,
#    'token': 5801,
#    'token_str': ' timing',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your timing for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"}],
#  [{'score': 0.13117742538452148,
#    'token': 529,
#    'token_str': ' meeting',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a meeting.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.07254696637392044,
#    'token': 46557,
#    'token_str': ' callback',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a callback.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.05493498221039772,
#    'token': 5209,
#    'token_str': ' presentation',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a presentation.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.04818817228078842,
#    'token': 633,
#    'token_str': ' job',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a job.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.04522285982966423,
#    'token': 2570,
#    'token_str': ' proposal',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a proposal.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"}],
#  [{'score': 0.3891046941280365,
#    'token': 473,
#    'token_str': ' does',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What does Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.36379605531692505,
#    'token': 16,
#    'token_str': ' is',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What is Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.051633384078741074,
#    'token': 18,
#    'token_str': "'s",
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What's Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.0500669926404953,
#    'token': 8901,
#    'token_str': ' Does',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What Does Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.023408059030771255,
#    'token': 32,
#    'token_str': ' are',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What are Blackrock<mask><mask>?:<mask><mask>,<mask>, and<mask>.</s>"}],
#  [{'score': 0.1313716620206833,
#    'token': 18,
#    'token_str': "'s",
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock's<mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.04681887477636337,
#    'token': 13,
#    'token_str': ' for',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock for<mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.038692694157361984,
#    'token': 11,
#    'token_str': ' in',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock in<mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.03767423704266548,
#    'token': 356,
#    'token_str': ' look',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock look<mask>?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.025632835924625397,
#    'token': 116,
#    'token_str': '?',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock?<mask>?:<mask><mask>,<mask>, and<mask>.</s>"}],
#  [{'score': 0.06980165094137192,
#    'token': 13,
#    'token_str': ' for',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask> for?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.03271075710654259,
#    'token': 47,
#    'token_str': ' you',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask> you?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.02450537122786045,
#    'token': 1820,
#    'token_str': ' Services',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask> Services?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.022440562024712563,
#    'token': 1839,
#    'token_str': ' offering',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask> offering?:<mask><mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.02047482691705227,
#    'token': 1753,
#    'token_str': ' Management',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask> Management?:<mask><mask>,<mask>, and<mask>.</s>"}],
#  [{'score': 0.24044719338417053,
#    'token': 3837,
#    'token_str': ' Thank',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?: Thank<mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.0421321764588356,
#    'token': 3303,
#    'token_str': ' Ag',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?: Ag<mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.034688662737607956,
#    'token': 660,
#    'token_str': ' An',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?: An<mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.019448297098279,
#    'token': 1437,
#    'token_str': ' ',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?: <mask>,<mask>, and<mask>.</s>"},
#   {'score': 0.01670878566801548,
#    'token': 1308,
#    'token_str': ' My',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?: My<mask>,<mask>, and<mask>.</s>"}],
#  [{'score': 0.029698146507143974,
#    'token': 1753,
#    'token_str': ' Management',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask> Management,<mask>, and<mask>.</s>"},
#   {'score': 0.024076683446764946,
#    'token': 6380,
#    'token_str': 'mail',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask>mail,<mask>, and<mask>.</s>"},
#   {'score': 0.018041906878352165,
#    'token': 29465,
#    'token_str': 'chat',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask>chat,<mask>, and<mask>.</s>"},
#   {'score': 0.014962275512516499,
#    'token': 10704,
#    'token_str': ' Name',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask> Name,<mask>, and<mask>.</s>"},
#   {'score': 0.0135165024548769,
#    'token': 29,
#    'token_str': 's',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask>s,<mask>, and<mask>.</s>"}],
#  [{'score': 0.021925996989011765,
#    'token': 9020,
#    'token_str': ' Marketing',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>, Marketing, and<mask>.</s>"},
#   {'score': 0.01928727887570858,
#    'token': 4706,
#    'token_str': ' Sales',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>, Sales, and<mask>.</s>"},
#   {'score': 0.013929437845945358,
#    'token': 1753,
#    'token_str': ' Management',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>, Management, and<mask>.</s>"},
#   {'score': 0.013912191614508629,
#    'token': 4557,
#    'token_str': ' Thanks',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>, Thanks, and<mask>.</s>"},
#   {'score': 0.013078958727419376,
#    'token': 3086,
#    'token_str': ' Adam',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>, Adam, and<mask>.</s>"}],
#  [{'score': 0.03303303197026253,
#    'token': 9020,
#    'token_str': ' Marketing',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and Marketing.</s>"},
#   {'score': 0.014724379405379295,
#    'token': 27585,
#    'token_str': ' Developers',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and Developers.</s>"},
#   {'score': 0.014072603546082973,
#    'token': 10657,
#    'token_str': ' Training',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and Training.</s>"},
#   {'score': 0.012895212508738041,
#    'token': 2573,
#    'token_str': ' Community',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and Community.</s>"},
#   {'score': 0.011826611123979092,
#    'token': 25980,
#    'token_str': ' Testing',
#    'sequence': "<s>Let’s talk about your<mask>! I am looking for new<mask> for the fintech company Blackrock to further increase its<mask>.    Based on your<mask>, I believe you,<mask>, could be<mask> in our<mask>.    Find the details here: https://careers.blackrock.com/job/16845601/<mask>    If you're<mask>, please let me know your<mask> and your<mask> for a<mask>.    What<mask> Blackrock<mask><mask>?:<mask><mask>,<mask>, and Testing.</s>"}]]

# %%
import random

new_chats = chats
toks = []
for ans in answer:
    toks.append(random.choice(ans)['token_str'])
toks

for tok in toks:
    new_chats = new_chats.replace(MASK_TOKEN, tok, 1)
new_chats
# Out:
# "Let’s talk about your  ideas! I am looking for new  applicants for the fintech company Blackrock to further increase its  presence.    Based on your  feedback, I believe you,  Adam, could be  participating in our  team.    Find the details here: https://careers.blackrock.com/job/16845601/ ...    If you're  interested, please let me know your  requirements and your  preferences for a  callback.    What  are Blackrock  look  for?:  My    mail,  Thanks, and  Developers."

# %%
answer[1][0]['sequence']

# %%
answer[2][0]['sequence']
