# %% [markdown]
# # Deep Q-Learning Applied to Algorithmic Trading
#
# <a href="https://www.kaggle.com/addarm/unsupervised-learning-as-signals-for-pairs-trading" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>
#
#
# <a href="https://colab.research.google.com/github/adamd1985/Deep-Q-Learning-Applied-to-Algorithmic-Trading/blob/main/drl_trading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# INTRO
#
#
# This deep learning network was inspired by the paper:
# ```BibTeX
# @article{theate2021application,
#   title={An application of deep reinforcement learning to algorithmic trading},
#   author={Th{\'e}ate, Thibaut and Ernst, Damien},
#   journal={Expert Systems with Applications},
#   volume={173},
#   pages={114632},
#   year={2021},
#   publisher={Elsevier}
# }
# ```

# %%
try:
  import google.colab

  # !sudo apt-get update
  # !sudo apt-get install -y xvfb freeglut3-dev
  # !pip install pyvirtualdisplay
  # !pip install tf-agents[reverb]
  # !pip install pyglet
  # !pip install tf-keras
  # !pip install shutil

  from google.colab import files
  IN_COLAB = True
except:
  IN_COLAB = False
  files = None

# %%
import os
os.environ['TF_USE_LEGACY_KERAS'] = '1' # KERAS 2 only for tfagents
import warnings
warnings.filterwarnings("ignore")
import shutil

IS_KAGGLE = os.getenv('IS_KAGGLE', 'True') == 'True'
if IN_COLAB or IS_KAGGLE:
    # Kaggle confgs
    print('Running in Kaggle or Collab...')
    # %pip install scikit-learn
    # %pip install tensorflow
    # %pip install tqdm
    # %pip install matplotlib
    # %pip install python-dotenv
    # %pip install yfinance
    # %pip install pyarrow
    for dirname, _, filenames in os.walk('/kaggle/input'):
        for filename in filenames:
            print(os.path.join(dirname, filename))

    DATA_DIR = "/kaggle/input/DATASET"
else:
    DATA_DIR = "./data/"
    print('Running Local...')
# Out:
# Running Local...

# %%
START_DATE = "2017-01-01"
SPLIT_DATE = '2018-1-1' # Turning point from train to tst
END_DATE = "2019-12-31" # pd.Timestamp(datetime.now() - BDay(1)).strftime('%Y-%m-%d')
DATA_DIR = "./data"
INDEX = "Date"
TARGET = 'TSLA'
TICKER_SYMBOLS = [TARGET]
INTERVAL = "1d"

MODELS_PATH = './models'
LOGS_PATH = './logs'

ACT_LONG = 2
ACT_HOLD = 1
ACT_SHORT = 0

CAPITAL = 100000
FEES = 0.1 / 100

FEATURES = ["Close", "High", "Low", "Open", "Volume"]
TARGET_FEATURE = "Price Raw"
STATE_LEN = 1
OBS_SPACE = (STATE_LEN)*len(FEATURES)
ACT_SPACE = 2

BATCH_SIZE = 64 # OBS_SPACE * 100
LEARN_RATE = 1e-3
TOTAL_ITERS = 10 # 10000
EPISODES = 10
INIT_COLLECT = 10 # 100
TOTAL_COLLECT = 1
LOG_INTERVALS = 1 # 200
TEST_INTERVALS = 2 # 1000
MEMORY_LENGTH = OBS_SPACE * 100

# %% [markdown]
# # Financial Data

# %%
import numpy as np
import math
import yfinance as yf
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt

from datetime import datetime
from pandas.tseries.offsets import BDay

from scipy.stats import skew, kurtosis

import tensorflow as tf
from tf_agents.specs import array_spec, tensor_spec
from tf_agents.trajectories import time_step as ts
from tf_agents.utils import common
from tf_agents.metrics import tf_metrics
from tf_agents.eval import metric_utils
from tf_agents.agents.dqn import dqn_agent
from tf_agents.drivers import py_driver
from tf_agents.environments import suite_gym, py_environment, tf_py_environment, utils
from tf_agents.networks import sequential
from tf_agents.policies import py_tf_eager_policy, policy_saver, random_tf_policy

import reverb
from tf_agents.replay_buffers import reverb_replay_buffer, reverb_utils

os.getcwd()
# Out:
# 2024-03-11 19:52:54.775206: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-11 19:52:54.775259: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-11 19:52:54.776257: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-11 19:52:54.782005: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-11 19:52:55.702513: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# '/mnt/c/Users/adamd/workspace/deep-reinforced-learning'

# %%
def get_tickerdata(tickers_symbols, start=START_DATE, end=END_DATE, interval=INTERVAL, datadir=DATA_DIR):
    tickers = {}
    earliest_end= datetime.strptime(end,'%Y-%m-%d')
    latest_start = datetime.strptime(start,'%Y-%m-%d')
    os.makedirs(DATA_DIR, exist_ok=True)
    for symbol in tickers_symbols:
        cached_file_path = f"{datadir}/{symbol}-{start}-{end}-{interval}.csv"

        try:
            if os.path.exists(cached_file_path):
                df = pd.read_parquet(cached_file_path)
                df.index = pd.to_datetime(df.index)
                assert len(df) > 0
            else:
                df = yf.download(
                    symbol,
                    start=START_DATE,
                    end=END_DATE,
                    progress=False,
                    interval=INTERVAL,
                )
                assert len(df) > 0
                df.to_parquet(cached_file_path, index=True, compression="snappy")
            min_date = df.index.min()
            max_date = df.index.max()
            nan_count = df["Close"].isnull().sum()
            skewness = round(skew(df["Close"].dropna()), 2)
            kurt = round(kurtosis(df["Close"].dropna()), 2)
            outliers_count = (df["Close"] > df["Close"].mean() + (3 * df["Close"].std())).sum()
            print(
                f"{symbol} => min_date: {min_date}, max_date: {max_date}, kurt:{kurt}, skewness:{skewness}, outliers_count:{outliers_count},  nan_count: {nan_count}"
            )
            tickers[symbol] = df

            if min_date > latest_start:
                latest_start = min_date
            if max_date < earliest_end:
                earliest_end = max_date
        except Exception as e:
            print(f"Error with {symbol}: {e}")

    return tickers, latest_start, earliest_end

tickers, latest_start, earliest_end = get_tickerdata(TICKER_SYMBOLS)
tickers[TARGET]
# Out:
# TSLA => min_date: 2017-01-03 00:00:00, max_date: 2019-12-30 00:00:00, kurt:-0.56, skewness:-0.28, outliers_count:0,  nan_count: 0
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2017-01-03  14.324000  14.688667  14.064000  14.466000  14.466000   88849500
# 2017-01-04  14.316667  15.200000  14.287333  15.132667  15.132667  168202500
# 2017-01-05  15.094667  15.165333  14.796667  15.116667  15.116667   88675500
# 2017-01-06  15.128667  15.354000  15.030000  15.267333  15.267333   82918500
# 2017-01-09  15.264667  15.461333  15.200000  15.418667  15.418667   59692500
# ...               ...        ...        ...        ...        ...        ...
# 2019-12-23  27.452000  28.134001  27.333332  27.948000  27.948000  199794000
# 2019-12-24  27.890667  28.364668  27.512667  28.350000  28.350000  120820500
# 2019-12-26  28.527332  28.898666  28.423332  28.729334  28.729334  159508500
# 2019-12-27  29.000000  29.020666  28.407333  28.691999  28.691999  149185500
# 2019-12-30  28.586000  28.600000  27.284000  27.646667  27.646667  188796000
#
# [753 rows x 6 columns]

# %% [markdown]
# # Trading Environment

# %%
class TradingEnv(py_environment.PyEnvironment):
    """
    A custom trading environment for reinforcement learning, compatible with tf_agents.

    This environment simulates a simple trading scenario where an agent can take one of three actions:
    - Long (buy), Short (sell), or Hold a financial instrument, aiming to maximize profit through trading decisions.

    Parameters:
    - data: DataFrame containing the stock market data.
    - data_dim: Dimension of the data to be used for each observation.
    - money: Initial capital to start trading.
    - state_length: Number of past observations to consider for the state.
    - transaction_cost: Costs associated with trading actions.
    """

    def __init__(self, data, features = FEATURES, money=CAPITAL, state_length=STATE_LEN, transaction_cost=FEES, market_costs=FEES // 2):
        super(TradingEnv, self).__init__()

        assert data is not None

        self.features = features
        self.data_dim = len(self.features)
        self.current_step = 0

        self.balance = money
        self.initial_balance = money
        self.transaction_cost = transaction_cost
        self.epsilon = market_costs
        self.total_shares = 0

        self.state_length = state_length
        self._episode_ended = False
        self._batch_size = 1
        self._action_spec = array_spec.BoundedArraySpec(shape=(), dtype=np.int32, minimum=ACT_SHORT, maximum=ACT_LONG, name='action')
        self._observation_spec = array_spec.BoundedArraySpec(shape=(self.data_dim,), dtype=np.float32, name='observation')

        self.data = self.preprocess_data(data.copy())

        self.reset()

    @property
    def batched(self):
        return False #True

    @property
    def batch_size(self):
        return None #self._batch_size

    @batch_size.setter
    def batch_size(self, size):
        self._batch_size = size

    def preprocess_data(self, df):
        def _log_rets(df):
            log_returns = np.log(df / df.shift(1))
            df = (log_returns - log_returns.mean()) / log_returns.std()
            df = df.dropna()
            return df


        price_raw = df['Close'].copy()
        df[self.features] = _log_rets(df[self.features])
        l = df[self.features]
        df = df.replace(0.0, np.nan)
        df = df.interpolate(method='linear', limit=5, limit_area='inside')
        df = df.ffill().bfill()

        df[TARGET_FEATURE] = price_raw
        df['Position'] = 0
        df['Action'] = ACT_HOLD
        df['Holdings'] = 0.
        df['Cash'] = float(self.balance)
        df['Money'] = df['Holdings'] + df['Cash']
        df['Returns'] = 0.

        assert not df.isna().any().any()

        return df

    def action_spec(self):
        """Provides the specification of the action space."""
        return self._action_spec

    def observation_spec(self):
        """Provides the specification of the observation space."""
        return self._observation_spec

    def _reset(self):
        """Resets the environment state and prepares for a new episode."""
        self.balance = self.initial_balance
        self.current_step = 0
        self._episode_ended = False
        self.total_shares = 0

        self.data['Position'] = 0
        self.data['Action'] = ACT_HOLD
        self.data['Holdings'] = 0.
        self.data['Cash']  = float(self.balance)
        self.data['Money'] = self.data.iloc[0]['Holdings'] + self.data.iloc[0]['Cash']
        self.data['Returns'] = 0.

        initial_observation = self._next_observation()
        return ts.restart(initial_observation)

    def _next_observation(self):
        """Generates the next observation based on the current step."""
        if self.current_step == 0 or self.state_length == 1:
            obs = self.data[self.features].iloc[0: self.current_step + 1]
        else:
            obs = self.data[self.features].iloc[min(0, self.current_step-self.state_length):self.current_step]
            assert len(obs) == self.state_length
        obs = obs.values[0]
        obs = obs.flatten().astype(np.float32)
        return obs

    def _step(self, action):
        """Executes a trading action and updates the environment's state."""
        if self._episode_ended:
            return self.reset()

        self.current_step += 1
        step_idx = self.data.index[self.current_step]
        current_price = self.data.iloc[self.current_step][TARGET_FEATURE]

        if self.current_step == 250 or  self.data.iloc[self.current_step].isna().any().any():
            assert not self.data.iloc[self.current_step].isna().any().any()

        if action == ACT_LONG:
            self._process_long_position(current_price)
        elif action == ACT_SHORT:
            self._process_short_position(current_price, self.data.iloc[self.current_step - 1][TARGET_FEATURE])
        elif action == ACT_HOLD:
            self.data.at[step_idx, "Cash"] = self.data.iloc[self.current_step - 1]["Cash"]
            self.data.at[step_idx, "Holdings"] = self.data.iloc[self.current_step - 1]["Holdings"]
            self.data.at[step_idx, "Position"] = self.data.iloc[self.current_step - 1]["Position"]
            self.data.at[step_idx, "Action"] = ACT_HOLD
        else:
          raise Exception(f"Invalid Actions: {action}")

        self._update_financials(current_price)
        done = self.current_step >= len(self.data) - 1
        reward = self._calculate_reward()
        print(f"act:{action} reward: {reward}, done: {done}, len: {len(self.data) }")
        if done:
            self._episode_ended = True
            return ts.termination(self._next_observation(), reward)
        else:
            return ts.transition(self._next_observation(), reward)

    def get_lower_bound(self, cash, total_shares, price):
        """
        Compute the lower bound of the action space, particularly for short selling,
        based on current cash, the number of shares, and the current price.
        """
        delta = -cash - total_shares * price * (1 + self.epsilon) * (1 + self.transaction_cost)
        if delta < 0:
            lowerBound = delta / (price * (2 * self.transaction_cost + self.epsilon * (1 + self.transaction_cost)))
        else:
            lowerBound = delta / (price * self.epsilon * (1 + self.transaction_cost))
        return lowerBound

    def _process_long_position(self, current_price):
        step_idx = self.data.index[self.current_step]
        cash_idx = self.data.columns.get_loc('Cash')

        self.data.at[step_idx, 'Position'] = 1

        if self.data.iloc[self.current_step - 1]['Position'] == 1:
            # more long
            self.data.at[step_idx, 'Cash'] = self.data.iloc[self.current_step - 1]['Cash']
            self.data.at[step_idx, 'Holdings'] = self.total_shares * current_price
        elif self.data.iloc[self.current_step - 1]['Position'] == 0:
            # new long
            self.total_shares = math.floor(self.data.iloc[self.current_step - 1]['Cash'] / (current_price * (1 + self.transaction_cost)))
            self.data.at[step_idx, 'Cash'] = self.data.iloc[self.current_step - 1]['Cash'] - self.total_shares * current_price * (1 + self.transaction_cost)
            self.data.at[step_idx, 'Holdings'] = self.total_shares * current_price
            self.data.at[step_idx, 'Action'] = 1
        else:
            # short to long
            self.data.at[step_idx, 'Cash'] = self.data.iloc[self.current_step - 1]['Cash'] - self.total_shares * current_price * (1 + self.transaction_cost)
            self.total_shares = math.floor(self.data.iloc[self.current_step, cash_idx] / (current_price * (1 + self.transaction_cost)))
            self.data.at[step_idx, 'Cash'] = self.data.iloc[self.current_step, cash_idx] - self.total_shares * current_price * (1 + self.transaction_cost)
            self.data.at[step_idx, 'Holdings'] = self.total_shares * current_price
            self.data.at[step_idx, 'Action'] = 1

    def _process_short_position(self, current_price, prev_price):
        """
        Adjusts the logic for processing short positions to include lower bound calculations.
        """
        step_idx = self.data.index[self.current_step]

        self.data.at[step_idx, 'Position'] = -1
        if self.data.iloc[self.current_step - 1]['Position'] == -1:
            # Short more
            lowerBound = self.get_lower_bound(self.data.iloc[self.current_step - 1]['Cash'], -self.total_shares, prev_price)
            if lowerBound <= 0:
                self.data.at[step_idx, 'Cash'] = self.data.iloc[self.current_step - 1]["Cash"]
                self.data.at[step_idx, 'Holdings'] = -self.total_shares * current_price
            else:
                total_sharesToBuy = min(math.floor(lowerBound), self.total_shares)
                self.total_shares -= total_sharesToBuy
                self.data.at[step_idx, 'Cash'] = self.data.iloc[self.current_step - 1]["Cash"] - total_sharesToBuy * current_price * (1 + self.transaction_cost)
                self.data.at[step_idx, 'Holdings'] = -self.total_shares * current_price
        elif self.data.iloc[self.current_step - 1]['Position'] == 0:
            self.total_shares = math.floor(self.data.iloc[self.current_step - 1]["Cash"] / (current_price * (1 + self.transaction_cost)))
            self.data.at[step_idx, 'Cash'] = self.data.iloc[self.current_step - 1]["Cash"] + self.total_shares * current_price * (1 - self.transaction_cost)
            self.data.at[step_idx, 'Holdings'] = -self.total_shares * current_price
            self.data.at[step_idx, 'Action'] = -1
        else:
            self.data.at[step_idx, 'Cash'] = self.data.iloc[self.current_step - 1]["Cash"] + self.total_shares * current_price * (1 - self.transaction_cost)
            self.total_shares = math.floor(self.data.iloc[self.current_step]["Cash"] / (current_price * (1 + self.transaction_cost)))
            self.data.at[step_idx, 'Cash'] = self.data.iloc[self.current_step]["Cash"] + self.total_shares * current_price * (1 - self.transaction_cost)
            self.data.at[step_idx, 'Holdings'] = -self.total_shares * current_price
            self.data.at[step_idx, 'Action'] = -1

    def _update_financials(self, current_price):
        """Updates the financial metrics including cash, money, and returns."""
        step_idx = self.data.index[self.current_step]

        self.data.at[step_idx,'Money'] = self.data.iloc[self.current_step]['Holdings'] + self.data.iloc[self.current_step]['Cash']
        self.data.at[step_idx,'Returns'] = ((self.data.iloc[self.current_step]['Money'] - self.data.iloc[self.current_step - 1]['Money'])) / self.data.iloc[self.current_step - 1]['Money']

    def _calculate_reward(self, reward_clip=1000):
        """
        Calculates the reward for the current step.
        """
        return np.clip(self.data.iloc[self.current_step]['Returns'], -reward_clip, reward_clip)

    def render(self, mode='human'):
        print(f'Step: {self.current_step}, Balance: {self.balance}')

stock= tickers[TARGET]
train_data = stock[stock.index < pd.to_datetime(SPLIT_DATE)].copy()
test_data = stock[stock.index >= pd.to_datetime(SPLIT_DATE)].copy()

train_env = TradingEnv(train_data)
utils.validate_py_environment(train_env, episodes=EPISODES)
test_env = TradingEnv(test_data)
utils.validate_py_environment(train_env, episodes=EPISODES//4)

print(f"TimeStep Specs: {train_env.time_step_spec()}")
print(f"Action Specs: {train_env.action_spec()}")
print(f"Reward Specs: {train_env.time_step_spec().reward}")

time_step = train_env.reset()
print(f'Time step: {time_step}')
action = np.array(ACT_HOLD, dtype=np.int32)
next_time_step = train_env.step(action)
print(f'Next time step: {next_time_step}')
# Out:
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.000998909341735998, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.013758395489391026, done: False, len: 251
# act:2 reward: -0.001399766808116454, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.03284216557706736, done: False, len: 251
# act:2 reward: 0.007128994881811806, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.038837446009652395, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.04036829271964978, done: False, len: 251
# act:0 reward: -0.002546666734721222, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.013091264934451981, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.005545715949518842, done: False, len: 251
# act:2 reward: 0.009267545250282118, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.02267755067423769, done: False, len: 251
# act:0 reward: 0.0011250974469326279, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.04741063021590125, done: False, len: 251
# act:0 reward: -0.0018866330272366257, done: False, len: 251
# act:0 reward: -0.042229740194066216, done: False, len: 251
# act:2 reward: -0.003559525165919325, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.04280860505831649, done: False, len: 251
# act:0 reward: 0.010171704990476102, done: False, len: 251
# act:2 reward: -0.020950118826572956, done: False, len: 251
# act:0 reward: -0.015956903480784948, done: False, len: 251
# act:2 reward: 0.062051711274277555, done: False, len: 251
# act:0 reward: 0.0019392490887133317, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.027155490994519308, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.006452262503578604, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.025116296156571565, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.003177141132674424, done: False, len: 251
# act:2 reward: -0.050046699291683976, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.013666140840446279, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.0004960679202703912, done: False, len: 251
# act:0 reward: 0.042867867452939225, done: False, len: 251
# act:2 reward: -0.017750050653811973, done: False, len: 251
# act:2 reward: -0.000901942144032297, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.060595613063735516, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.026437933952279044, done: False, len: 251
# act:2 reward: -0.0033650250904062274, done: False, len: 251
# act:0 reward: 0.0705082520233751, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.0026008376442119055, done: False, len: 251
# act:2 reward: 0.012854688195804674, done: False, len: 251
# act:0 reward: 0.030492486668978788, done: False, len: 251
# act:2 reward: 0.009781080300409282, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.017223513288177686, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.010336965515900602, done: False, len: 251
# act:2 reward: 0.01755057206361266, done: False, len: 251
# act:0 reward: -0.011829427971078176, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.018246696056617998, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.00720533337762862, done: False, len: 251
# act:0 reward: 0.005222817301430717, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.04790814407464574, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.039707972712939944, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.010563771031617441, done: False, len: 251
# act:2 reward: 0.0017638491846151128, done: False, len: 251
# act:0 reward: 0.04370897107336237, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.014746380261832436, done: False, len: 251
# act:2 reward: 0.0035768732251399565, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.012458509826472949, done: False, len: 251
# act:0 reward: -0.009105721553427593, done: False, len: 251
# act:0 reward: 0.0015440084034467243, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.00041754533958347843, done: False, len: 251
# act:0 reward: -0.0212208939528343, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.06196324725785999, done: False, len: 251
# act:2 reward: 0.017634230841904703, done: False, len: 251
# act:2 reward: -0.0018764899244026769, done: False, len: 251
# act:2 reward: -0.001527530187577118, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.0361730592268309, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.01745641662351281, done: False, len: 251
# act:0 reward: -0.048857949357527033, done: False, len: 251
# act:0 reward: -0.014282234233143586, done: False, len: 251
# act:2 reward: 0.01419698814780983, done: False, len: 251
# act:2 reward: -0.010495694085592448, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.00025915988230664025, done: False, len: 251
# act:2 reward: -0.01317161391483181, done: False, len: 251
# act:2 reward: 0.016497655757690566, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.013381128806932015, done: False, len: 251
# act:2 reward: -0.04005205855431617, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.004470411546620529, done: False, len: 251
# act:2 reward: 0.002383786286040604, done: False, len: 251
# act:0 reward: -0.026807911971903544, done: False, len: 251
# act:0 reward: 0.07239212791238388, done: False, len: 251
# act:0 reward: 0.04828226032431506, done: False, len: 251
# act:0 reward: -0.011073158625025442, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.043372010109848654, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.032128342500681764, done: False, len: 251
# act:2 reward: -0.02912319324202821, done: False, len: 251
# act:0 reward: -0.011057656895549516, done: False, len: 251
# act:2 reward: -0.01632455876144641, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.036113934665977024, done: False, len: 251
# act:0 reward: 0.00852450127347916, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.014878535240857464, done: False, len: 251
# act:0 reward: -0.0017398505905897998, done: False, len: 251
# act:0 reward: 0.033143386697669, done: False, len: 251
# act:0 reward: 0.010785584810912631, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.0974023874321155, done: False, len: 251
# act:0 reward: -0.030464327811193615, done: False, len: 251
# act:2 reward: 0.0031443010708684708, done: False, len: 251
# act:2 reward: -0.02235988450958341, done: False, len: 251
# act:2 reward: 0.00694861608790652, done: False, len: 251
# act:2 reward: 0.01656709766098224, done: False, len: 251
# act:2 reward: -0.004039914988214832, done: False, len: 251
# act:2 reward: 0.0016004946000774637, done: False, len: 251
# act:2 reward: -0.030277412532229393, done: False, len: 251
# act:0 reward: -0.014643171348761204, done: False, len: 251
# act:2 reward: 0.025625595215771072, done: False, len: 251
# act:2 reward: 0.010328958542712397, done: False, len: 251
# act:0 reward: 0.03138850401093236, done: False, len: 251
# act:0 reward: -0.0004535018822785386, done: False, len: 251
# act:0 reward: 0.013836663395298666, done: False, len: 251
# act:2 reward: 0.004712673820269992, done: False, len: 251
# act:2 reward: 0.004917724512158413, done: False, len: 251
# act:0 reward: 0.014722444825119875, done: False, len: 251
# act:2 reward: -0.009697975570672436, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.019688712755709818, done: False, len: 251
# act:2 reward: 0.012475259396001304, done: False, len: 251
# act:2 reward: 0.017645006233534346, done: False, len: 251
# act:2 reward: -0.02056157506008348, done: False, len: 251
# act:2 reward: 0.05907798574844836, done: False, len: 251
# act:2 reward: -0.002584351979828931, done: False, len: 251
# act:0 reward: 0.007575365635991945, done: False, len: 251
# act:0 reward: -0.031149583152089648, done: False, len: 251
# act:0 reward: -0.006114612867716814, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.016727268782757432, done: False, len: 251
# act:2 reward: 0.018677938074586394, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.05863684293668216, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.011652052089627583, done: False, len: 251
# act:2 reward: -0.004017796178804645, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.0056829878834098535, done: False, len: 251
# act:2 reward: 0.019353315843551395, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.01861273968484977, done: False, len: 251
# act:0 reward: -0.004361622811732727, done: False, len: 251
# act:2 reward: 0.03739211822180567, done: False, len: 251
# act:0 reward: 0.03480939352759115, done: False, len: 251
# act:0 reward: 0.0027838246520230383, done: False, len: 251
# act:2 reward: -0.0050206577461004475, done: False, len: 251
# act:2 reward: -0.00030922601330461014, done: False, len: 251
# act:2 reward: -0.01397490337379887, done: False, len: 251
# act:2 reward: 0.014686320634722503, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.013048646693364268, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.04112436117008208, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.04304056874400531, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.03321931660893333, done: False, len: 251
# act:0 reward: -0.03345275843708421, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.04468399607839849, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.005553432779686925, done: False, len: 251
# act:2 reward: -0.0045990215607656345, done: False, len: 251
# act:2 reward: 0.0, done: False, len: 251
# act:2 reward: 0.04095502224229873, done: False, len: 251
# act:0 reward: -0.023196559052066173, done: False, len: 251
# act:0 reward: -0.008421657074052959, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.014264698582508683, done: False, len: 251
# act:2 reward: -0.020027470340229878, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.010479000285601026, done: False, len: 251
# act:0 reward: -0.009435594505488974, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.008474810447188364, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.04361446082736651, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.03763517976258387, done: False, len: 251
# act:2 reward: 0.04372732111971768, done: False, len: 251
# act:0 reward: 0.034776774498400276, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.007209478184898844, done: False, len: 251
# act:2 reward: 0.0164534849196572, done: False, len: 251
# act:0 reward: -0.015305191532794523, done: False, len: 251
# act:0 reward: 0.022927734647536283, done: False, len: 251
# act:2 reward: 0.004162521831229539, done: False, len: 251
# act:2 reward: 0.008145285425479428, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.043321577675895694, done: False, len: 251
# act:2 reward: -0.01780452094241063, done: False, len: 251
# act:2 reward: 0.011935163354291515, done: False, len: 251
# act:1 reward: 0.0, done: True, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.000998909341735998, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.013758395489391026, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.0007737806829431867, done: False, len: 251
# act:0 reward: 0.033472255265905686, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.00256562455445221, done: False, len: 251
# act:2 reward: -0.02477367034231037, done: False, len: 251
# act:2 reward: 0.003979090622075781, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.0403699169801327, done: False, len: 251
# act:0 reward: -0.0025467898578124424, done: False, len: 251
# act:2 reward: 0.005704295987130799, done: False, len: 251
# act:2 reward: 0.001742456422202954, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.014666640785420047, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.00838534096949544, done: False, len: 251
# act:2 reward: 0.025623230651365306, done: False, len: 251
# act:2 reward: -0.0011250961410189993, done: False, len: 251
# act:0 reward: 0.015831601819685338, done: False, len: 251
# act:0 reward: -0.02716367060418658, done: False, len: 251
# act:2 reward: -0.0021712925862199944, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.04364037764140556, done: False, len: 251
# act:2 reward: -0.00434169138166527, done: False, len: 251
# act:2 reward: -0.03863808074605382, done: False, len: 251
# act:2 reward: 0.012194822312278832, done: False, len: 251
# act:0 reward: 0.016917762262296132, done: False, len: 251
# act:0 reward: 0.013985791718584646, done: False, len: 251
# act:0 reward: 0.06228116735320742, done: False, len: 251
# act:0 reward: -0.003379901815898948, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.021576351124493715, done: False, len: 251
# act:0 reward: -0.00016173936946634707, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.004912308487888798, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.027065675320416163, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.04422100836543875, done: False, len: 251
# act:0 reward: -0.026999624387809406, done: False, len: 251
# act:2 reward: 0.00026646618128618044, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.041376037935595376, done: False, len: 251
# act:2 reward: 0.017272820140368836, done: False, len: 251
# act:0 reward: -0.0028980429960642606, done: False, len: 251
# act:0 reward: -0.032886020740496194, done: False, len: 251
# act:0 reward: -0.028647940566047293, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.02991056525779433, done: False, len: 251
# act:0 reward: -0.00232533407808904, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.09111290866065645, done: False, len: 251
# act:0 reward: 0.01531731551111226, done: False, len: 251
# act:0 reward: 0.02864618644253301, done: False, len: 251
# act:2 reward: -0.013785847309143742, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.04582953773281899, done: False, len: 251
# act:0 reward: -0.013753851811760682, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.015255594470438309, done: False, len: 251
# act:2 reward: 0.006199293384879374, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.013534244702042354, done: False, len: 251
# act:2 reward: -0.009851501680869222, done: False, len: 251
# act:2 reward: 0.010213939590000113, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.02679824128152783, done: False, len: 251
# act:2 reward: -0.011535744702716521, done: False, len: 251
# act:2 reward: -0.004964759314330574, done: False, len: 251
# act:0 reward: 0.015592196445629532, done: False, len: 251
# act:0 reward: -0.027891447127361236, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.036626227030655975, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.00858326652471656, done: False, len: 251
# act:0 reward: -0.005751595136335359, done: False, len: 251
# act:0 reward: -0.04579802097156779, done: False, len: 251
# act:0 reward: -0.013508512031500178, done: False, len: 251
# act:0 reward: 0.0073308236896665385, done: False, len: 251
# act:0 reward: -0.005869985489819416, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.026933771341270334, done: False, len: 251
# act:2 reward: 0.03458753702064757, done: False, len: 251
# act:0 reward: 0.020656604521328215, done: False, len: 251
# act:0 reward: 0.007122334852377348, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.020120296557142116, done: False, len: 251
# act:2 reward: 0.02092740445481828, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.045993796102755335, done: False, len: 251
# act:2 reward: -0.0326255037862467, done: False, len: 251
# act:2 reward: 0.017636423797899578, done: False, len: 251
# act:0 reward: -0.003870803566652695, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.020415570787468886, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.06801087897481156, done: False, len: 251
# act:2 reward: 0.03861033901761753, done: False, len: 251
# act:0 reward: 0.0027217955010094353, done: False, len: 251
# act:0 reward: -0.04718325149046885, done: False, len: 251
# act:0 reward: -0.013768441448530006, done: False, len: 251
# act:2 reward: 0.01364274630866761, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.016725474705237296, done: False, len: 251
# act:2 reward: -0.008595614760040378, done: False, len: 251
# act:2 reward: 0.011172667310979519, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.016690325167759257, done: False, len: 251
# act:0 reward: 0.015541086978054687, done: False, len: 251
# act:0 reward: 0.038823025704798265, done: False, len: 251
# act:2 reward: -0.02381753875882187, done: False, len: 251
# act:0 reward: -0.030192760774842585, done: False, len: 251
# act:0 reward: -0.002383414725454457, done: False, len: 251
# act:0 reward: 0.024974649378259103, done: False, len: 251
# act:0 reward: 0.06919547464664323, done: False, len: 251
# act:0 reward: 0.04628821662961009, done: False, len: 251
# act:0 reward: -0.010636072254472708, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.03428395800357845, done: False, len: 251
# act:2 reward: -0.007660185406160699, done: False, len: 251
# act:0 reward: -0.020501436614265945, done: False, len: 251
# act:2 reward: -0.015506999501566488, done: False, len: 251
# act:0 reward: -0.02699011678596608, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.03437941096298214, done: False, len: 251
# act:0 reward: -0.006595659369287577, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.03409949520684119, done: False, len: 251
# act:2 reward: -0.015464542416451278, done: False, len: 251
# act:0 reward: -0.029246794955382, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.030860820694982333, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.07301812089007804, done: False, len: 251
# act:0 reward: 0.02623719622224954, done: False, len: 251
# act:2 reward: 0.0028765142398263902, done: False, len: 251
# act:2 reward: 0.028290912262194975, done: False, len: 251
# act:0 reward: -0.006614948717565977, done: False, len: 251
# act:0 reward: 0.022361096772436327, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.024552495335020418, done: False, len: 251
# act:0 reward: -0.006030294521912623, done: False, len: 251
# act:0 reward: -0.0016007730496805273, done: False, len: 251
# act:0 reward: 0.03037977850901496, done: False, len: 251
# act:2 reward: 0.010023189751532857, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.01758302286269679, done: False, len: 251
# act:2 reward: 0.033452040015813804, done: False, len: 251
# act:0 reward: -0.0015451223190949153, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.015780120352512993, done: False, len: 251
# act:2 reward: -0.018198948125176785, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.004274696249924436, done: False, len: 251
# act:0 reward: 0.0163451761091862, done: False, len: 251
# act:2 reward: 0.012040603664354577, done: False, len: 251
# act:2 reward: 0.01764710771506629, done: False, len: 251
# act:2 reward: -0.02056398143304136, done: False, len: 251
# act:0 reward: 0.05696916467336289, done: False, len: 251
# act:0 reward: 0.0025842659995310466, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.042822161986474566, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.006724730216027422, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.08209377719377645, done: False, len: 251
# act:0 reward: -0.0007536188293033024, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.008790951522094944, done: False, len: 251
# act:0 reward: 0.017314872658197027, done: False, len: 251
# act:2 reward: -0.02172704452113436, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.0032584541253328856, done: False, len: 251
# act:0 reward: 0.03905970314297301, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.03144299590066119, done: False, len: 251
# act:0 reward: -0.0030069592967570057, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.0021867223370902514, done: False, len: 251
# act:0 reward: 0.008942416341460186, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.040447439667746915, done: False, len: 251
# act:2 reward: 0.01966821978418882, done: False, len: 251
# act:2 reward: 0.0009493666264676133, done: False, len: 251
# act:2 reward: -0.03408787805689744, done: False, len: 251
# act:0 reward: -0.0009871087854813635, done: False, len: 251
# act:2 reward: 0.014248606376621613, done: False, len: 251
# act:0 reward: -0.004454541730302051, done: False, len: 251
# act:0 reward: -0.03576635468569452, done: False, len: 251
# act:0 reward: 0.033853516162199455, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.057342853023973135, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.0047713551643913145, done: False, len: 251
# act:2 reward: 0.002264542074776394, done: False, len: 251
# act:2 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.027422900147320517, done: False, len: 251
# act:0 reward: 0.0018488891157453962, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.018986812252422554, done: False, len: 251
# act:2 reward: -0.016390314884923894, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.01144051128712164, done: False, len: 251
# act:2 reward: -0.0043334267267658225, done: False, len: 251
# act:2 reward: -0.03152256509731581, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.01656420366939268, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.007966453850494416, done: False, len: 251
# act:0 reward: 0.04163978534304508, done: False, len: 251
# act:2 reward: -0.038845560173285665, done: False, len: 251
# act:2 reward: -0.0058644468095333645, done: False, len: 251
# act:2 reward: -0.0033624662697716245, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.0008967088439569583, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.03833593694756189, done: False, len: 251
# act:2 reward: -0.02432258361865839, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.008068281218165154, done: False, len: 251
# act:2 reward: 0.010717553007283125, done: True, len: 251
# act:2 reward: -0.0009989073214624659, done: False, len: 251
# act:2 reward: -0.0010572024496262084, done: False, len: 251
# act:2 reward: 0.009965958877181911, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.0017496380756598202, done: False, len: 251
# act:0 reward: 0.0006090188741815196, done: False, len: 251
# act:0 reward: 0.0006086481959424541, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.03810317336128475, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.03084644153404309, done: False, len: 251
# act:0 reward: 0.015086125643820444, done: False, len: 251
# act:2 reward: -0.024854872700815975, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.017596784519809856, done: False, len: 251
# act:0 reward: -0.005186358677778061, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.00048428596370987247, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.02267710952269655, done: False, len: 251
# act:2 reward: -0.0008728919851461514, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.045517828829757544, done: False, len: 251
# act:2 reward: 0.00011148565384126177, done: False, len: 251
# act:2 reward: 0.0422312438651164, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.0029935536447289186, done: False, len: 251
# act:2 reward: -0.03864003506628744, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.02932039731769467, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.07150604139626265, done: False, len: 251
# act:2 reward: -0.04190357300186188, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.015390926362968299, done: False, len: 251
# act:2 reward: 0.001839810025283497, done: False, len: 251
# act:2 reward: 0.004351288090682493, done: False, len: 251
# act:0 reward: -0.0034258313786999714, done: False, len: 251
# act:0 reward: 0.01042795711037777, done: False, len: 251
# act:0 reward: 0.006775116017876374, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.010478038649361084, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.04730551414492505, done: False, len: 251
# act:0 reward: -0.024711893355020883, done: False, len: 251
# act:0 reward: 0.0022050736565806953, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.04328408027374597, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.017680234731548842, done: False, len: 251
# act:0 reward: 0.030825404508970134, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.0562982178201229, done: False, len: 251
# act:0 reward: -0.002249566523863646, done: False, len: 251
# act:2 reward: -0.003944207377804062, done: False, len: 251
# act:2 reward: 0.0013670833973468627, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.08708618920215781, done: False, len: 251
# act:0 reward: 0.030490029750711328, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.04977684172185313, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.02646790770943012, done: False, len: 251
# act:2 reward: 0.007473044238345887, done: False, len: 251
# act:2 reward: 0.010213228369820346, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.026796394123602872, done: False, len: 251
# act:0 reward: -0.01350976044512051, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.01457113127392108, done: False, len: 251
# act:0 reward: 0.02583773339569092, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.03457885732377426, done: False, len: 251
# act:0 reward: -0.05192448908933543, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.03969878899016582, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.06354282884285485, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.0015430530503951422, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.029309390626191992, done: False, len: 251
# act:0 reward: 0.03979187473913572, done: False, len: 251
# act:2 reward: -0.026473484056148085, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.008655914067806804, done: False, len: 251
# act:0 reward: -0.022866571290302565, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.10279461904970097, done: False, len: 251
# act:2 reward: -0.023901316488633948, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.016465976894567812, done: False, len: 251
# act:0 reward: -0.015918852766828147, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.05219735775672402, done: False, len: 251
# act:2 reward: -0.03426343728616785, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.06317795975140363, done: False, len: 251
# act:0 reward: 0.013972284805372274, done: False, len: 251
# act:2 reward: 0.008235250715860815, done: False, len: 251
# act:2 reward: -0.004307380873915466, done: False, len: 251
# act:2 reward: 0.0065971646312713425, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.027854267847473912, done: False, len: 251
# act:2 reward: 0.0021951215102740296, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.056854579852266676, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.0044701470237439814, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.02233331983655057, done: False, len: 251
# act:0 reward: 0.06859952369039894, done: False, len: 251
# act:0 reward: 0.04591514837029527, done: False, len: 251
# act:0 reward: -0.010554112117057512, done: False, len: 251
# act:2 reward: -0.008635469161439787, done: False, len: 251
# act:0 reward: 0.03326955625576998, done: False, len: 251
# act:2 reward: -0.009026688290002699, done: False, len: 251
# act:0 reward: -0.02050187025323387, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.009873634118294805, done: False, len: 251
# act:2 reward: 0.027127110178552006, done: False, len: 251
# act:0 reward: -0.011057479042538928, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.009653718504128115, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.04998030045011151, done: False, len: 251
# act:0 reward: -0.029248946515374255, done: False, len: 251
# act:0 reward: -0.0018237841510849915, done: False, len: 251
# act:0 reward: 0.03474520539261454, done: False, len: 251
# act:0 reward: 0.011289348371106497, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.08068562759974476, done: False, len: 251
# act:2 reward: 0.02828854343104009, done: False, len: 251
# act:2 reward: -0.0048745824645757534, done: False, len: 251
# act:2 reward: 0.028292559520883664, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.0038875975648493383, done: False, len: 251
# act:2 reward: -0.00404014105016768, done: False, len: 251
# act:2 reward: 0.0016005845224230549, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.044479656420445365, done: False, len: 251
# act:2 reward: 0.025625402505174543, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.044125011815034525, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.020152253821374012, done: False, len: 251
# act:0 reward: 0.002909885147418793, done: False, len: 251
# act:2 reward: -0.018751021202726297, done: False, len: 251
# act:2 reward: 0.007700362078346789, done: False, len: 251
# act:0 reward: -0.003399607545767612, done: False, len: 251
# act:0 reward: 0.016344568855691237, done: False, len: 251
# act:0 reward: 0.014005795977802129, done: False, len: 251
# act:0 reward: -0.016596679072242066, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.035668952208780476, done: False, len: 251
# act:0 reward: 0.00757474745538791, done: False, len: 251
# act:0 reward: -0.03115248582887448, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.020740986027276063, done: False, len: 251
# act:0 reward: 0.028489823402633466, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.06718083552108584, done: False, len: 251
# act:0 reward: 0.01599360405001622, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.010374087386386685, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.002201013246920375, done: False, len: 251
# act:0 reward: -0.0007397363017134953, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.04146194443789096, done: False, len: 251
# act:0 reward: -0.001098332545076034, done: False, len: 251
# act:0 reward: -0.004361804369518398, done: False, len: 251
# act:2 reward: 0.037393630597313786, done: False, len: 251
# act:2 reward: 0.03688411470612658, done: False, len: 251
# act:2 reward: -0.002783903958670996, done: False, len: 251
# act:2 reward: 0.0030454864200719087, done: False, len: 251
# act:2 reward: -0.0003092622648937581, done: False, len: 251
# act:2 reward: -0.013976542204810073, done: False, len: 251
# act:2 reward: 0.01468806730575659, done: False, len: 251
# act:0 reward: 0.008942339551675258, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.03845044562870509, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.057688901317713016, done: False, len: 251
# act:0 reward: -0.0010126318126135049, done: False, len: 251
# act:2 reward: 0.01428067890541126, done: False, len: 251
# act:0 reward: -0.004454690789179151, done: False, len: 251
# act:2 reward: -0.03776917844748395, done: False, len: 251
# act:0 reward: -0.03345031445926956, done: False, len: 251
# act:0 reward: 0.06795639289656571, done: False, len: 251
# act:0 reward: -0.01991788741119098, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.009224058086306818, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.03847977322399868, done: False, len: 251
# act:0 reward: -0.023196242302714637, done: False, len: 251
# act:0 reward: -0.008421533958401306, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.012249682742013553, done: False, len: 251
# act:2 reward: 0.01882789737219937, done: False, len: 251
# act:0 reward: 0.02731948295228071, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.003146312580961427, done: False, len: 251
# act:2 reward: -0.004312600803441816, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.02933769925162304, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.01181671301232471, done: False, len: 251
# act:0 reward: 0.004799386711917446, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.02597495514610821, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.09351316773384469, done: False, len: 251
# act:2 reward: 0.003865842963641957, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.01303618670466211, done: False, len: 251
# act:0 reward: -0.01530537972175788, done: False, len: 251
# act:0 reward: 0.02292633603601708, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.0016152818256778062, done: False, len: 251
# act:0 reward: 0.018663945583763417, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.036538867798633766, done: False, len: 251
# act:0 reward: 0.009914935478136221, done: False, len: 251
# act:2 reward: 0.010716469668115026, done: True, len: 251
# act:0 reward: -0.0009989073214627569, done: False, len: 251
# act:2 reward: -0.0009406467333381711, done: False, len: 251
# act:0 reward: 0.007948480096828005, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.003755223194417317, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.0007781227491615563, done: False, len: 251
# act:2 reward: 0.0355374580326802, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.0005625113910165402, done: False, len: 251
# act:0 reward: -0.022652507695391743, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.024191552103563847, done: False, len: 251
# act:2 reward: 0.022858030472879712, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.008504560428803976, done: False, len: 251
# act:2 reward: 0.007173371764141519, done: False, len: 251
# act:2 reward: 0.005186511714496358, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.0015082487690736284, done: False, len: 251
# act:0 reward: -0.0028706851890220107, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.026466264221920367, done: False, len: 251
# act:2 reward: 0.017864926106565093, done: False, len: 251
# act:2 reward: 0.027166409010693282, done: False, len: 251
# act:2 reward: 0.00011148291804663744, done: False, len: 251
# act:0 reward: 0.04014798909671832, done: False, len: 251
# act:0 reward: -0.0013540771489180506, done: False, len: 251
# act:0 reward: 0.004353173390026017, done: False, len: 251
# act:0 reward: 0.038404881386631555, done: False, len: 251
# act:0 reward: -0.011221904106832955, done: False, len: 251
# act:2 reward: -0.01979428019099638, done: False, len: 251
# act:2 reward: -0.013985996139364576, done: False, len: 251
# act:2 reward: -0.0640489299274102, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.021521645237833325, done: False, len: 251
# act:2 reward: 0.004351081314949427, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.01381842307772242, done: False, len: 251
# act:2 reward: 0.00492104223188702, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.004827330496532385, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.06449931604994284, done: False, len: 251
# act:2 reward: 0.0002525111315570717, done: False, len: 251
# act:2 reward: 0.0016058428699325606, done: False, len: 251
# act:0 reward: -0.04481865683213915, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.018351551891480418, done: False, len: 251
# act:0 reward: 0.030823619655766805, done: False, len: 251
# act:2 reward: -0.028822184629100158, done: False, len: 251
# act:0 reward: 0.024699321147249674, done: False, len: 251
# act:2 reward: -0.0017454876161322483, done: False, len: 251
# act:2 reward: 0.0019465519474765277, done: False, len: 251
# act:2 reward: 0.001367165115208634, done: False, len: 251
# act:0 reward: 0.07050498367295815, done: False, len: 251
# act:2 reward: -0.01935006844320063, done: False, len: 251
# act:2 reward: -0.028642958618360668, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.02555579044455331, done: False, len: 251
# act:0 reward: 0.030490686339616376, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.02485659399710604, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.00499933313675932, done: False, len: 251
# act:0 reward: -0.011828863514577532, done: False, len: 251
# act:2 reward: -0.01221201667332202, done: False, len: 251
# act:0 reward: 0.005936740151434392, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.008944534700841895, done: False, len: 251
# act:0 reward: -0.006952692628009042, done: False, len: 251
# act:2 reward: -0.01962345370896792, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.01534496015507464, done: False, len: 251
# act:2 reward: -0.024676280274196546, done: False, len: 251
# act:0 reward: -0.05192042895325439, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.041691200961773076, done: False, len: 251
# act:2 reward: 0.04580014660340683, done: False, len: 251
# act:0 reward: 0.010303362111902166, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.02871822572345363, done: False, len: 251
# act:2 reward: -0.005319633672433635, done: False, len: 251
# act:0 reward: -0.03630955481250798, done: False, len: 251
# act:0 reward: -0.022699024277153198, done: False, len: 251
# act:2 reward: 0.005408407559123533, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.024373555189429096, done: False, len: 251
# act:2 reward: -0.022926170310377494, done: False, len: 251
# act:0 reward: 0.01926464705821549, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.05765520481423435, done: False, len: 251
# act:2 reward: -0.02191124676776803, done: False, len: 251
# act:2 reward: -0.0018763103147654324, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.020414418122907646, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.033424023020745465, done: False, len: 251
# act:2 reward: -0.030775439874611177, done: False, len: 251
# act:0 reward: -0.03619342036850215, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.05213271627711122, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.01132494997299119, done: False, len: 251
# act:0 reward: -0.006296702218762971, done: False, len: 251
# act:0 reward: -0.006596933417124155, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.030234204897173256, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.013380234457240207, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.018519303645254954, done: False, len: 251
# act:0 reward: 0.028246442748050455, done: False, len: 251
# act:0 reward: -0.0022520966084016176, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.09060265986660346, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.03337955605024237, done: False, len: 251
# act:0 reward: -0.00659070377329185, done: False, len: 251
# act:0 reward: -0.026185995184711573, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.009172002175575926, done: False, len: 251
# act:0 reward: -0.010424477355051927, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.0011089345335561713, done: False, len: 251
# act:2 reward: 0.00540147247252369, done: False, len: 251
# act:0 reward: 0.012297788963463244, done: False, len: 251
# act:2 reward: 0.0026084420935755617, done: False, len: 251
# act:2 reward: 0.04298815963356301, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.0038822017008754484, done: False, len: 251
# act:2 reward: -0.027303418940176547, done: False, len: 251
# act:2 reward: 0.0018234898235077084, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.046250316212749804, done: False, len: 251
# act:2 reward: 0.019772695227743005, done: False, len: 251
# act:0 reward: 0.06291261073209563, done: False, len: 251
# act:2 reward: -0.030283993291231572, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.023282509310787517, done: False, len: 251
# act:0 reward: -0.00661578525973654, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.015566568001355753, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.015616102711763948, done: False, len: 251
# act:0 reward: -0.03221849264672612, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.03994320542852402, done: False, len: 251
# act:2 reward: -0.011454952788867032, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.03185721310780738, done: False, len: 251
# ...
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.007810993374929475, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.014959327705706713, done: False, len: 251
# act:0 reward: 0.016392115507849723, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.013032245995394933, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.027082989979168855, done: False, len: 251
# act:2 reward: 0.0042596193031241136, done: False, len: 251
# act:2 reward: -0.007511737663101876, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.01991362622811473, done: False, len: 251
# act:2 reward: 0.004450247589122945, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.09351531904418448, done: False, len: 251
# act:2 reward: 0.0038660396345933387, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.013036798950280763, done: False, len: 251
# act:2 reward: -0.0133348390030151, done: False, len: 251
# act:2 reward: -0.022928315634776042, done: False, len: 251
# act:0 reward: -0.008387846683385582, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.052705885634429274, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.0010605220704884661, done: True, len: 251
# act:2 reward: -0.0009989073214624659, done: False, len: 251
# act:0 reward: -0.0030529331831048814, done: False, len: 251
# act:0 reward: -0.009966242919196615, done: False, len: 251
# act:0 reward: -0.01011117174605305, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.029113360160649894, done: False, len: 251
# act:0 reward: 0.010057312150236246, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.03961301916452297, done: False, len: 251
# act:0 reward: 0.001972957037335944, done: False, len: 251
# act:2 reward: -0.019117655634856963, done: False, len: 251
# act:0 reward: 0.02081407530806256, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.008247397028043687, done: False, len: 251
# act:2 reward: -0.0036953100420639012, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.0055338499293783065, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.022676109824313482, done: False, len: 251
# act:0 reward: 0.0011249579725641113, done: False, len: 251
# act:0 reward: -0.0178228022958131, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.03023723489977495, done: False, len: 251
# act:2 reward: 0.04222669120215228, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.0029932440051406725, done: False, len: 251
# act:0 reward: -0.040556613833804704, done: False, len: 251
# act:2 reward: -0.014191963794361896, done: False, len: 251
# act:2 reward: 0.018953229042429447, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.07714238863675114, done: False, len: 251
# act:2 reward: 0.003945166950953656, done: False, len: 251
# act:0 reward: -0.04381761376512826, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.0173877018312423, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.006198381006415143, done: False, len: 251
# act:2 reward: -0.0014307504722362349, done: False, len: 251
# act:0 reward: -0.012404439419993958, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.017711162767902633, done: False, len: 251
# act:2 reward: 0.010175700745546053, done: False, len: 251
# act:0 reward: 0.04595727229936446, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.015695054673709963, done: False, len: 251
# act:0 reward: 0.0021654371015592073, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.02549669848829016, done: False, len: 251
# act:0 reward: 0.0008812196592109676, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.05909792809308311, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.0334205405717702, done: False, len: 251
# act:0 reward: -0.0006334529658165637, done: False, len: 251
# act:2 reward: -0.07465279103142326, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.011788829702826062, done: False, len: 251
# act:2 reward: 0.012539550835147862, done: False, len: 251
# act:2 reward: 0.012852818732743623, done: False, len: 251
# act:0 reward: 0.030488035067364607, done: False, len: 251
# act:2 reward: 0.009780410369316832, done: False, len: 251
# act:2 reward: -0.03844546026489942, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.013465767510758236, done: False, len: 251
# act:2 reward: 0.001949808576504945, done: False, len: 251
# act:2 reward: 0.017548512586210294, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.0002617777490030196, done: False, len: 251
# act:2 reward: 0.007950026553639362, done: False, len: 251
# act:0 reward: 0.016660693840216262, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.00288998028844326, done: False, len: 251
# act:0 reward: 0.025833874564574755, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.034581896949822534, done: False, len: 251
# act:2 reward: -0.050021199297314314, done: False, len: 251
# act:0 reward: 0.04153504787595676, done: False, len: 251
# act:0 reward: 0.0037611712820919832, done: False, len: 251
# act:2 reward: -0.047439555493699125, done: False, len: 251
# act:2 reward: 0.01232466814782323, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.0012605444554692877, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.02596029594524704, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.017494905355150133, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.022418399142190893, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.04059066423676263, done: False, len: 251
# act:2 reward: -0.02822287779241745, done: False, len: 251
# act:0 reward: 0.028569128815098255, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.05296069407169062, done: False, len: 251
# act:0 reward: -0.021423871697713842, done: False, len: 251
# act:2 reward: -0.03547761114240091, done: False, len: 251
# act:0 reward: -0.036187265940561375, done: False, len: 251
# act:0 reward: -0.004729012494075912, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.06287653540234116, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.02432228892329523, done: False, len: 251
# act:2 reward: -0.004307321179401851, done: False, len: 251
# act:2 reward: 0.006597072807917612, done: False, len: 251
# act:0 reward: 0.009153760939493568, done: False, len: 251
# act:2 reward: -0.018492899218726787, done: False, len: 251
# act:2 reward: 0.0021948255628810144, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.05495925412988074, done: False, len: 251
# act:2 reward: 0.024470463039886193, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.02787816323176399, done: False, len: 251
# act:0 reward: 0.0248510639470987, done: False, len: 251
# act:0 reward: 0.06886136823221096, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.03500098961634435, done: False, len: 251
# act:0 reward: -0.006900024933343706, done: False, len: 251
# act:0 reward: -0.027423520098038542, done: False, len: 251
# act:0 reward: -0.005805970321036197, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.025263780263442448, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.023656914319298557, done: False, len: 251
# act:0 reward: 0.04090110980220594, done: False, len: 251
# act:2 reward: 0.006527040024974949, done: False, len: 251
# act:2 reward: 0.012513783553691555, done: False, len: 251
# act:2 reward: -0.02730641935439049, done: False, len: 251
# act:0 reward: -0.0001777200335992502, done: False, len: 251
# act:0 reward: 0.03461420970010155, done: False, len: 251
# act:2 reward: 0.009317463036922253, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.08609355858193979, done: False, len: 251
# act:0 reward: 0.026231531778047434, done: False, len: 251
# act:2 reward: 0.0028769964532901295, done: False, len: 251
# act:0 reward: 0.026233834573510677, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.02488513232130994, done: False, len: 251
# act:0 reward: 0.004938142270289677, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.014458948626622267, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.041028908942728474, done: False, len: 251
# act:2 reward: -0.027621321056237824, done: False, len: 251
# act:0 reward: 0.008308514036561826, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.03591725974954647, done: False, len: 251
# act:2 reward: -0.013826692535876747, done: False, len: 251
# act:2 reward: -0.006866550757371514, done: False, len: 251
# act:0 reward: 0.0029101668788673444, done: False, len: 251
# act:2 reward: -0.018752488454789263, done: False, len: 251
# act:2 reward: 0.0077013807840583945, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.01969203927759367, done: False, len: 251
# act:2 reward: 0.012475188794857223, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.005270422385156843, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.10168926478686702, done: False, len: 251
# act:2 reward: 0.005745030115039639, done: False, len: 251
# act:0 reward: 0.011637129805011573, done: False, len: 251
# act:2 reward: 0.02370998412258276, done: False, len: 251
# act:2 reward: -0.0031718370192891227, done: False, len: 251
# act:0 reward: -0.021825256270807187, done: False, len: 251
# act:2 reward: 0.03998958551491323, done: False, len: 251
# act:0 reward: -0.019332815518574693, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.011651473879017687, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.0003724638491398989, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.0201771212126809, done: False, len: 251
# act:0 reward: -0.02009535055864407, done: False, len: 251
# act:2 reward: -0.003012607290055939, done: False, len: 251
# act:2 reward: 0.0043607724585868176, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.008371468491884339, done: False, len: 251
# act:0 reward: -0.003044965270137546, done: False, len: 251
# act:0 reward: 0.0003110983197305689, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.011534720561785339, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.06269794801624498, done: False, len: 251
# act:0 reward: -0.0010502104050585223, done: False, len: 251
# act:2 reward: 0.03208386102157949, done: False, len: 251
# act:0 reward: -0.000987244371085071, done: False, len: 251
# act:0 reward: 0.016248522652550928, done: False, len: 251
# act:2 reward: 0.00041721346625128285, done: False, len: 251
# act:2 reward: 0.03577042938601641, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.07857568491129102, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.0001306333493635562, done: False, len: 251
# act:0 reward: 0.005420949613883974, done: False, len: 251
# act:0 reward: 0.004547293104700149, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: -0.04012567437856032, done: False, len: 251
# act:0 reward: 0.02256893045506351, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.022932420726809812, done: False, len: 251
# act:2 reward: -0.020022904209649795, done: False, len: 251
# act:0 reward: 0.027312945728066303, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.0031454851550286275, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: 0.027076303135616143, done: False, len: 251
# act:2 reward: 0.004259370333597007, done: False, len: 251
# act:0 reward: -0.009493939123109578, done: False, len: 251
# act:2 reward: 0.002340184367891824, done: False, len: 251
# act:2 reward: -0.00491334258282202, done: False, len: 251
# act:0 reward: 0.029409046033131898, done: False, len: 251
# act:2 reward: 0.004449382152481723, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:0 reward: 0.054661562176833836, done: False, len: 251
# act:0 reward: -0.036841103313406065, done: False, len: 251
# act:2 reward: 0.0042378976853767346, done: False, len: 251
# act:0 reward: -0.005352894353961709, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.004897472906151132, done: False, len: 251
# act:2 reward: -0.02292513029664678, done: False, len: 251
# act:2 reward: -0.006401810200774395, done: False, len: 251
# act:1 reward: 0.0, done: False, len: 251
# act:2 reward: -0.011487945315225775, done: False, len: 251
# act:2 reward: -0.02431911080385067, done: False, len: 251
# act:0 reward: -0.019765769327884968, done: False, len: 251
# act:0 reward: -0.011934138318353998, done: False, len: 251
# act:2 reward: 0.010998038228797, done: True, len: 251
# TimeStep Specs: TimeStep(
# {'step_type': ArraySpec(shape=(), dtype=dtype('int32'), name='step_type'),
#  'reward': ArraySpec(shape=(), dtype=dtype('float32'), name='reward'),
#  'discount': BoundedArraySpec(shape=(), dtype=dtype('float32'), name='discount', minimum=0.0, maximum=1.0),
#  'observation': BoundedArraySpec(shape=(5,), dtype=dtype('float32'), name='observation', minimum=-3.4028234663852886e+38, maximum=3.4028234663852886e+38)})
# Action Specs: BoundedArraySpec(shape=(), dtype=dtype('int32'), name='action', minimum=0, maximum=2)
# Reward Specs: ArraySpec(shape=(), dtype=dtype('float32'), name='reward')
# Time step: TimeStep(
# {'step_type': array(0, dtype=int32),
#  'reward': array(0., dtype=float32),
#  'discount': array(1., dtype=float32),
#  'observation': array([ 1.9550354 ,  1.6273892 ,  0.6523866 , -0.08771443,  1.6908462 ],
#       dtype=float32)})
# act:1 reward: 0.0, done: False, len: 251
# Next time step: TimeStep(
# {'step_type': array(1, dtype=int32),
#  'reward': array(0., dtype=float32),
#  'discount': array(1., dtype=float32),
#  'observation': array([ 1.9550354 ,  1.6273892 ,  0.6523866 , -0.08771443,  1.6908462 ],
#       dtype=float32)})

# %% [markdown]
# # The Problem Definition
#
# We are teaching an agent to trade in an environment with many unknowns. Our objective to make sequential interaction that lead to the highest sharpe ratio.
#
# Let's formulize our policy, which is finding the optimal action *a_t* given state *s_t* to maximize our expected reward *r_t*:
#
# $$
# \pi^*(a_t | s_t) = \arg\max_{a \in \mathcal{A}} \mathbb{E} \left[ \sum_{t=0}^{\infty} \gamma^t r_t \middle| s_t = f(o_1, a_1, r_1, \ldots, o_t), a_t \right]
# $$
#
# At each timestep *t*:
#
# 1. Observe the environments state *s_t* and map history with *f(.)*
# 2. Observations *o_t* from history *h_t*, have previous actions *a_t-1*, previous observations *o_t-1* and their returns *r_t-1*. For our experiment, we'll encode these into features for a network.
# 3. Execute action *a_t*, which can be: hold, long, short
# 4. Get returns *r_t* discounted at *γ_t*. *γ* is the discounting factor to prevent the agent from doing only tactical choices for returns in the present (missing better future returns).
#
#
# The *π(a_t|h_t)* creates an action on quantity *at = Qt*. Where a positive *Q* is the long, the negative *Q* signals a short and when its 0 no action is taken.

# %% [markdown]
# ## Actions and Rewards
#
# A core concept in RL is rewards engineering.
#
# Let's look at our action space *A* at time *t*:
#
# $$
# a_t = Q_t \in \{Q_{\text{Long}, t}, Q_{\text{Short}, t}\}
# $$
#
# The action *Q_Long,t* is set to maximize returns on a buy, given our liquidity *vc_t* (the value *v* of our portfolio with cash remainng *c*) and purchasing *Q_long* at price *p* shares (transaction costs *C*) if we are not already long:
#
# $$
# Q_{\text{Long}, t} =
# \begin{cases}
# \left\lfloor \frac{v_{c,t}}{p_t (1 + C)}\right\rfloor & \text{if } a_{t-1} \neq Q_{\text{Long}, t-1}, \\
# 0 & \text{otherwise}.
# \end{cases}
# $$
#
# The action *Q_Short,t* aims to convert a **negative** number of shares to returns (shorting is the borrowing of shares, therefore our *v_c* will be initially negative).
#
# $$
# \hat{Q}_{\text{Short}, t} =
# \begin{cases}
# -2n_t - \left\lfloor \frac{v_{c,t}}{p_t (1 + C)}\right\rfloor & \text{if } a_{t-1} \neq Q_{\text{Short}, t-1}, \\
# 0 & \text{otherwise}.
# \end{cases}
# $$
#
# Note the *-2n* is an indication to sell twice, meaning not close a long position but open a short position, also for the *Qn* shares, we need to negate the amount we can buy, as its a short position. If we had no shares to start, then *-2(0)* will not have an effect save for the short amount:
#
# $$
# \hat{Q}_{\text{Short}, t} = -\left\lfloor \frac{v_{c,t}}{p_t (1 + C)} \right\rfloor
# $$
#
# We need to have boundaries, as a short can have infinite loss:
#
# $$
# Q_{\text{Short}, t} = \max\{\hat{Q}_{\text{Short}, t}, Q_t\}
# $$
#
# Given that our portfolio cannot fall into negative amounts, we need to model constraints.
# 1. Cash value *vc_t* needs to be large enough to return to neutral *n_t=0*.
# 2. To return to 0, we need to adjust for costs *C* of market volatility epsiloc *ϵ*.
# 3. We redifine the action space permissable to ensure we can always return to neutral.
#
# $$
# v_{c,t+1} \geq -n_{t+1} p_t (1 + \varepsilon)(1 + C)
# $$
#
# The action space *A* is redefined as a set of acceptable values for *Q_t* between boundaries *Q-* and *Q+*:
#
# $$
# A = \left\{ Q_t \in \mathbb{Z} \cap \left[Q_t^-, Q_t^+\right] \right\}
# $$
#
# Where the top boundary *Q+* is:
# $$
# Q_t^+ = \frac{v_{c,t}}{p_t (1+C)}
# $$
#
# And the lower boundary *Q-* is (for both coming out of a long where delta *t* is positive, or reversing a short and incurring twice the costs with delta *t* in the negative):
#
# $$
# Q_t^- = \begin{cases}
#     \frac{\Delta t}{p_t \varepsilon (1 + C)} & \text{if } \Delta t \geq 0, \\
#     \frac{\Delta t}{p_t (2C + \varepsilon(1 + C))} & \text{if } \Delta t < 0,
#     \end{cases}
# $$
#
# with *delta t* being the in change of portfolio value in time:
#
# $$
#  t_Δ = -v_{c,t} - n_t p_t (1 + \varepsilon)(1 + C)
# $$
#
# In the above boundaries, the cost of trading is defined as:
#
# $$
# v_{c,t+1} = v_{c,t} - Q_t p_t - C |Q_t| p_t
# $$
#
# Where *C* is the percentage cost of the transaction given the absolute quantity *|Q_t|* of shares and their price *p_t*.

# %% [markdown]
# ## Agent's Objective
#
# As initially declared in this section, our agent's aim is to maximize the sharpe ratio:
#
# $$
# \max_{\pi} \left( \frac{E\left[\sum_{t=0}^{T} \gamma^t r_t - R_f\right]}{\sqrt{\mathrm{Var}\left[\sum_{t=0}^{T} \gamma^t r_t\right]}} \right)
# $$
#
# which is just the maximization of:
#
# $$
# \text{sharpe}= \left( \frac{\bar{R} - R_f}{\sigma} \right)
# $$
#
# or the returns of the portfolio (annualized) minus the risk free rate (at the time of writing, 5%) divided by the volatility or standard deviation of the portfolio

# %% [markdown]
# # Deep Q-Network Architecure

# %% [markdown]
# ## Architecture
#
# 2 models:
# - Policy Model: This is the primary model that the agent uses to make decisions or select actions based on the current state of the environment. The policy model is actively trained and updated throughout the training process based on the agent's experiences. In real-life applications, after the training phase is complete, the policy model is what gets deployed to make decisions or take actions in the given environment.
# - Target Model: The target model is used exclusively during the training phase to provide a stable target for the temporal difference (TD) error calculation, which is crucial for the stability of the Q-learning updates. The target model's weights are periodically synchronized with the policy model's weights but at a much slower rate. This delayed update helps to stabilize the learning process by making the target for the policy updates more consistent across training batches. The target model itself is not used for decision-making or action selection outside of the training context.
#
# Some notes on this 2 model arch:
# - Stability/Reducing Temporal Correlations: The agent learns a policy that maps states to actions by using a Q-function. This Q-function estimates the rewards by taking a certain action in a given state. The learning process continuously updates the Q-values based on new experiences. If the Q-function is constantly changing—as it would be when updates are made based on estimates from the same function—it can lead to unstable training dynamics. The estimates can become overly optimistic, and the learning process can diverge.
# - Target: The target network is a stable baseline for the policy network to compare against. While the policy network is frequently updated to reflect the latest learning, the target network's weights are updated less frequently. This slower update rate provides a fixed target for the policy network to aim for over multiple iterations, making the learning process more stable.
#
# In practice, the policy network is responsible for selecting actions during training and gameplay. Its weights are regularly updated to reflect the agent's learning. The target network, on the other hand, is used to generate the Q-value targets for the updates of the policy network. Every few steps, the weights from the policy network are copied to the target network, ensuring the target for the updates remains relatively stable but still gradually adapts to the improved policy. The policy model is used both during training (for learning and decision-making) and after training (for decision-making in the deployment environment).
#
# The target model is used during the training process only, to calculate stable target values for updating the policy model.
# After training is complete and the model is deployed in a real-world application, only the policy model is used to make decisions or take actions based on the learned policy. The target model's role ends with the completion of the training phase, as its primary purpose is to aid in the convergence and stability of the training process itself.

# %% [markdown]
# ## DRL Flow
#
# - Initialization: init policy network and the target network with the same architecture but separate parameters.
# - Data Preparation: Normalize input data using calculated coefficients to ensure consistency in scale.
# - Learning Process:
#     -At each training step, observe the current market state and process it through normalization.
#     - Select an action using the epsilon-greedy policy (a balance between exploration and exploitation) based on the current state.
#     - Execute the selected action in the simulated trading environment, observe the next state, and receive a reward based on the action's outcome.
#     - Store the experience (current state, action, reward, next state) in the replay memory.
#     - Sample a random batch of past experiences from the replay memory for learning to reduce correlation between consecutive learning steps.
#     - Use the policy network to predict Q-values for the current states and the target network to calculate the target Q-values for the next states.
#     - Update the policy network by minimizing the difference between its Q-value predictions and the target Q-values using backpropagation.
#     - Every few steps, update the target network's parameters with the policy network's parameters to gradually adapt the learning target.
# - Evaluation and Adjustment: Periodically test the trained policy network on a separate validation set or environment to evaluate performance.
#     -Repeat the learning and evaluation process for many episodes until the policy network stabilizes and performs satisfactorily.
# - Application Phase
#     - Model Deployment: Deploy the trained policy network in a real-world environment or a simulation that closely mimics real trading conditions.
#     - Real-time Operation: Observe the current market state and process it (normalization, etc.) as done during training.
#     - Use the trained policy network to select the action that maximizes expected rewards based on the current market state, leaning towards exploitation of the learned policy over exploration. Execute the selected action in the market (buy, sell, hold).
# - Continuous Learning:
#     - Repeat the learning process with new market data and experiences, possibly in a less frequent, offline manner.
#     - Update the policy and target networks as new data becomes available and as the market evolves to maintain or improve performance over time.

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
for gpu in tf.config.experimental.list_physical_devices('GPU'):
    tf.config.experimental.set_memory_growth(gpu, True)

def create_q_network(env, fc_layer_params = (100, 50)):
    env = tf_py_environment.TFPyEnvironment(env)

    action_tensor_spec = tensor_spec.from_spec(env.action_spec())
    num_actions = action_tensor_spec.maximum - action_tensor_spec.minimum + 1

    def _dense_layer(num_units):
        return tf.keras.layers.Dense(
            num_units,
            activation=tf.keras.activations.relu,
            kernel_initializer=tf.keras.initializers.VarianceScaling(
                scale=2.0, mode='fan_in', distribution='truncated_normal'))

    dense_layers = [_dense_layer(num_units) for num_units in fc_layer_params]
    q_values_layer = tf.keras.layers.Dense(
        num_actions,
        activation=None,
        kernel_initializer=tf.keras.initializers.RandomUniform(
            minval=-0.03, maxval=0.03),
        bias_initializer=tf.keras.initializers.Constant(-0.2))
    q_net = sequential.Sequential(dense_layers + [q_values_layer])

    return q_net

def create_agent(q_net, env, train_step_counter=None, optimizer = tf.keras.optimizers.Adam(learning_rate=LEARN_RATE)):
    env = tf_py_environment.TFPyEnvironment(env)

    if train_step_counter is None:
      train_step_counter = tf.compat.v1.train.get_or_create_global_step()

    agent = dqn_agent.DqnAgent(
        env.time_step_spec(),
        env.action_spec(),
        q_network=q_net,
        optimizer=optimizer,
        epsilon_greedy = 0.5,
        td_errors_loss_fn=common.element_wise_squared_loss,
        train_step_counter=train_step_counter,
        name="TradeAgent")

    agent.initialize()
    print(agent.policy)
    print(agent.collect_policy)
    return agent, train_step_counter

q_net = create_q_network(train_env)
agent, train_step_counter = create_agent(q_net, train_env)

# %% [markdown]
# # Trading Operations

# %%
class TradingSimulator:
    def __init__(self, env, eval_env, agent, episodes=EPISODES,
                 batch_size=BATCH_SIZE, num_eval_episodes=TEST_INTERVALS,
                 collect_steps_per_iteration=INIT_COLLECT,
                 replay_buffer_max_length=MEMORY_LENGTH ,
                 num_iterations = TOTAL_ITERS, log_interval=LOG_INTERVALS,
                 eval_interval=TEST_INTERVALS, global_step=None):
        self.py_env = env
        self.env =  tf_py_environment.TFPyEnvironment(self.py_env)
        self.py_eval_env = eval_env
        self.eval_env =  tf_py_environment.TFPyEnvironment(self.py_eval_env)
        self.agent = agent
        self.episodes = episodes
        self.log_interval = log_interval
        self.eval_interval = eval_interval
        self.global_step = global_step

        self.batch_size = batch_size
        self.num_eval_episodes = num_eval_episodes
        self.collect_steps_per_iteration = collect_steps_per_iteration
        self.replay_buffer_max_length = replay_buffer_max_length
        self.num_iterations = num_iterations

        self.policy = self.agent.policy
        self.collect_policy = self.agent.collect_policy
        self.random_policy = random_tf_policy.RandomTFPolicy(
            self.env.time_step_spec(),
            self.env.action_spec())

        self.replay_buffer_signature = tensor_spec.from_spec(
            self.agent.collect_data_spec)
        self.replay_buffer_signature = tensor_spec.add_outer_dim(
            self.replay_buffer_signature)

    def compute_episode_metrics(self, environment, policy, num_eval_episodes):
        total_returns = sharpe_ratio = std_dev = avg_return = 0.

        for _ in range(num_eval_episodes):
            time_step = self.env.reset()
            episode_returns = []

            while not time_step.is_last():
                action_step = policy.action(time_step)
                time_step = environment.step(action_step.action)
                episode_returns.append(time_step.reward)

            total_returns += np.sum(episode_returns)
            avg_return += np.mean(episode_returns)
            std_dev += np.std(episode_returns)
            sharpe_ratio += avg_return / std_dev if std_dev > 0 else 0

            print(f'step = {self.agent.train_step_counter.numpy()}: Average Return = {avg_return}, Total Return = {total_returns}, Sharpe = {sharpe_ratio}')

        return total_returns, avg_return, std_dev, sharpe_ratio

    def init_memory(self, table_name = 'uniform_table'):
        self.table = reverb.Table(
            table_name,
            max_size=self.replay_buffer_max_length,
            sampler=reverb.selectors.Uniform(),
            remover=reverb.selectors.Fifo(),
            rate_limiter=reverb.rate_limiters.MinSize(1),
            signature=self.replay_buffer_signature)

        self.reverb_server = reverb.Server([self.table])
        self.replay_buffer = reverb_replay_buffer.ReverbReplayBuffer(
                                    self.agent.collect_data_spec,
                                    table_name=table_name,
                                    sequence_length=2,
                                    local_server=self.reverb_server)

        self.rb_observer = reverb_utils.ReverbAddTrajectoryObserver(self.replay_buffer.py_client, table_name, sequence_length=2)

        print(self.agent.collect_data_spec)
        print(self.agent.collect_data_spec._fields)

        # Test with random actions
        py_driver.PyDriver(
            self.py_env,
            py_tf_eager_policy.PyTFEagerPolicy(self.random_policy, True),
            [self.rb_observer],
            max_steps=self.collect_steps_per_iteration).run(self.py_env.reset())
        time_step = self.env.reset()
        for i in range(10):
          action_step = self.random_policy.action(time_step)
          time_step = self.env.step(action_step.action)
          print(f"Random Step {i}: {self.random_policy.action(time_step)}")
          if time_step.is_last():
              break

        self.compute_episode_metrics(self.eval_env, self.random_policy, self.num_eval_episodes)
        self.dataset = self.replay_buffer.as_dataset(num_parallel_calls=3, sample_batch_size=self.batch_size, num_steps=2).prefetch(3)

        iterator = iter(self.dataset)
        print(iterator)

        return self.dataset, iterator

    def train(self, checkpoint_path=MODELS_PATH):
        _, iterator = self.init_memory()


        if self.global_step is None:
          self.global_step = tf.compat.v1.train.get_or_create_global_step()

        checkpoint_dir = os.path.join(checkpoint_path, 'checkpoint')
        train_checkpointer = common.Checkpointer(
            ckpt_dir=checkpoint_dir,
            max_to_keep=1,
            agent=agent,
            policy=agent.policy,
            replay_buffer=self.replay_buffer,
            global_step=self.global_step
        )
        train_checkpointer.initialize_or_restore()
        self.global_step = tf.compat.v1.train.get_global_step()

        self.agent.train = common.function(self.agent.train)
        self.agent.train_step_counter.assign(self.global_step )

        # Agent's first eval
        total_returns, avg_return, std_dev, sharpe_ratio = self.compute_episode_metrics(self.eval_env, self.agent.policy, self.num_eval_episodes)
        metrics = [[total_returns, avg_return, std_dev, sharpe_ratio]]

        time_step = self.py_env.reset()
        collect_driver = py_driver.PyDriver(
            self.py_env,
            py_tf_eager_policy.PyTFEagerPolicy(self.agent.collect_policy, use_tf_function=True),
            [self.rb_observer],
            max_steps=self.collect_steps_per_iteration)

        for _ in tqdm(range(self.num_iterations), desc="Training Loop"):
            time_step, _ = collect_driver.run(time_step)
            experience, _ = next(iterator)
            train_loss = self.agent.train(experience).loss
            step = self.agent.train_step_counter.numpy()

            if step % self.log_interval == 0:
                print('step = {0}: loss = {1}'.format(step, train_loss))
                train_checkpointer.save(self.global_step)

            if step % self.eval_interval == 0:
                total_returns, avg_return, std_dev, sharpe_ratio = self.compute_episode_metrics(self.eval_env, self.agent.policy, self.num_eval_episodes)
                print('step = {0}: Average Return = {1}, Total Return = {2}, Sharpe = {3}'.format(step, avg_return, total_returns, sharpe_ratio))
                metrics.append([total_returns, avg_return, std_dev, sharpe_ratio])

            # Later call: saved_policy = tf.saved_model.load(policy_dir)
            train_checkpointer.save(self.global_step)

        totals, average, _, sharpe_ratios = zip(*metrics)
        print(f'\nTraining completed. Mean Reward: {np.mean(average):.4f}, Mean Totals: {np.mean(totals):.4f}, Mean Loss: {np.mean(train_loss):.4f}')

        policy_dir = os.path.join(checkpoint_path, 'policy')
        tf_policy_saver = policy_saver.PolicySaver(agent.policy)
        tf_policy_saver.save(policy_dir)

        return metrics

    def plot_performance(self, metrics):
        """
        Plot the training performance including average returns and Sharpe Ratios on the same plot,
        with returns on the left y-axis and Sharpe Ratios on the right y-axis.
        """
        _, average_returns, _, sharpe_ratios = zip(*metrics)  # Ignore std deviations as per your request
        iterations = range(0, self.num_iterations + 1, self.eval_interval)
        iterations = list(iterations)[:len(average_returns)]

        fig, ax1 = plt.subplots(figsize=(10, 6))

        color = 'tab:blue'
        ax1.set_xlabel('Iterations')
        ax1.set_ylabel('Average Return', color=color)
        ax1.plot(iterations, average_returns, label='Average Return', color=color)
        ax1.tick_params(axis='y', labelcolor=color)

        ax2 = ax1.twinx()
        color = 'tab:green'
        ax2.set_ylabel('Sharpe Ratio', color=color)
        ax2.plot(iterations, sharpe_ratios, label='Sharpe Ratio', color=color)
        ax2.tick_params(axis='y', labelcolor=color)

        fig.tight_layout()
        plt.title('Training Performance: Average Returns and Sharpe Ratios')
        plt.show()

sim = TradingSimulator(train_env, test_env, agent=agent, global_step=train_step_counter)
metrics = sim.train()
sim.plot_performance(metrics)

# %% [markdown]
# # Conclusion
#
# CONCLUDE

# %% [markdown]
# ## References
#
# - [TensorFlow Agents](https://www.tensorflow.org/agents/overview)
# - [Open Gym AI Github](https://github.com/openai/gym)
# - [Greg et al, OpenAI Gym, (2016)](https://arxiv.org/abs/1606.01540)
# - [Théate, Thibaut, and Damien Ernst. "An application of deep reinforcement learning to algorithmic trading." Expert Systems with Applications 173 (2021): 114632.](https://www.sciencedirect.com/science/article/pii/S0957417421000737)
# - [Remote development in WSL](https://code.visualstudio.com/docs/remote/wsl-tutorial)
# - [NVIDIA Driver Downloads](https://www.nvidia.com/Download/index.aspx)
# - [CUDA Toolkit](https://developer.nvidia.com/cuda-toolkit-archive)
# - [TensorRT for CUDA](https://docs.nvidia.com/deeplearning/tensorrt/archives/index.html#trt_7)

# %% [markdown]
# ## Github
#
# Article here is also available on [Github](https://github.com/adamd1985/pairs_trading_unsupervised_learning)
#
# Kaggle notebook available [here](https://www.kaggle.com/code/addarm/unsupervised-learning-as-signals-for-pairs-trading)
#
# ## Media
#
# All media used (in the form of code or images) are either solely owned by me, acquired through licensing, or part of the Public Domain and granted use through Creative Commons License.
#
# ## CC Licensing and Use
#
# <a rel="license" href="http://creativecommons.org/licenses/by-nc/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc/4.0/88x31.png" /></a><br />This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc/4.0/">Creative Commons Attribution-NonCommercial 4.0 International License</a>.
